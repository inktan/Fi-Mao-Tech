# %%
import urbanity as urb
# Out:
# c:\Users\20228\Anaconda3\lib\site-packages\geopandas\_compat.py:124: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
m = urb.Map('Singapore', zoom=11)
m
# Out:
# Map(center=[1.357107, 103.8194992], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %%
m.add_bbox(show=True)
m
# Out:
# No bounding box/polygon found. Please draw on map.
# Map(bottom=260367.0, center=[1.357107, 103.8194992], controls=(ZoomControl(options=['position', 'zoom_in_text'…
# Map(bottom=260367.0, center=[1.357107, 103.8194992], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %%
m1 = urb.Map('Singapore')
m1
# Out:
# Map(center=[1.357107, 103.8194992], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…
# created
# {'type': 'Feature', 'properties': {'style': {'stroke': True, 'color': '#a52a2a', 'weight': 4, 'opacity': 0.5, 'fill': True, 'fillColor': None, 'fillOpacity': 0.2, 'clickable': True}}, 'geometry': {'type': 'Polygon', 'coordinates': [[[103.733604, 1.294209], [103.733604, 1.393746], [103.899772, 1.393746], [103.899772, 1.294209], [103.733604, 1.294209]]]}}

# %%
m1.add_bbox(remove = False)
# Out:
# Assigned bbox attribute to self object.

# %%
print(m1.polygon_bounds)
# Out:
#                                             geometry
# 0  POLYGON ((103.73360 1.29421, 103.73360 1.39375...

# %%
m1.polygon_bounds.geometry.values[0]
# Out:
# <POLYGON ((103.734 1.294, 103.734 1.394, 103.9 1.394, 103.9 1.294, 103.734 1...>

# %%
m2 = urb.Map('Singapore')
m2
# Out:
# Map(center=[1.357107, 103.8194992], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…

# %%
m2.add_polygon_boundary('../shapefile/tanjong_pagar_singapore_4326.shp')

# %%
m2.polygon_bounds.geometry.values[0]
# Out:
# <POLYGON ((103.842 1.273, 103.843 1.273, 103.844 1.273, 103.844 1.273, 103.8...>

# %%
SG, SG_nodes, SG_edges = m2.get_street_network('Singapore'
                                           )
# Out:
# Creating data folder and downloading osm street data...
# Data extracted successfully. Proceeding to construct street network.
# --- 6.737 seconds ---
# c:\Users\20228\Anaconda3\lib\site-packages\pandas\core\common.py:228: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(7,7))
SG_nodes.plot(ax=ax, color='green', markersize=0.1)
SG_edges.plot(ax=ax, color='black', linewidth=0.1)
plt.show()

# %%
print(list(SG_nodes.columns))
# Out:
# ['x', 'y', 'tags', 'timestamp', 'version', 'changeset', 'osmid', 'geometry']

# %%
SG_nodes.head()
# Out:
#                      x         y                            tags  timestamp  \
# osmid
# 1363479432  103.836654  1.272482                            None          0
# 6897440292  103.843801  1.272658                            None          0
# 237154345   103.843888  1.272790  {'highway': 'traffic_signals'}          0
# 246801933   103.839936  1.272953                            None          0
# 4600797369  103.828686  1.273515                            None          0
#
#             version  changeset       osmid                   geometry
# osmid
# 1363479432        0          0  1363479432  POINT (103.83665 1.27248)
# 6897440292        0          0  6897440292  POINT (103.84380 1.27266)
# 237154345         0          0   237154345  POINT (103.84389 1.27279)
# 246801933         0          0   246801933  POINT (103.83994 1.27295)
# 4600797369        0          0  4600797369  POINT (103.82869 1.27352)

# %%
print(list(SG_edges.columns))
# Out:
# ['access', 'bicycle', 'bridge', 'foot', 'footway', 'highway', 'junction', 'lanes', 'lit', 'maxspeed', 'name', 'oneway', 'psv', 'ref', 'service', 'sidewalk', 'smoothness', 'surface', 'tunnel', 'osmid', 'timestamp', 'version', 'tags', 'osm_type', 'geometry', 'length']

# %%
SG2, SG2_nodes, SG2_edges = m2.get_street_network('Singapore', dual=True)
# Out:
# Creating data folder and downloading osm street data...
# Data extracted successfully. Proceeding to construct street network.
# c:\Users\20228\Anaconda3\lib\site-packages\pandas\core\common.py:228: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)
# --- 7.263 seconds ---

# %%
SG2_nodes.columns
# Out:
# Index(['length', 'osmids', 'x', 'y', 'geometry'], dtype='object')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(7,7))
SG2_nodes.plot(ax=ax, color='green', markersize=0.1)
SG2_edges.plot(ax=ax, color='black', linewidth=0.1)
plt.show()
